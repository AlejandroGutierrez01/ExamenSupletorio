# %%
import pandas as pd

# %%
df_tokio = pd.read_csv("C:/Users/ANALISIS DE DATOS.1-21-01-E019-27/Desktop/Datasets/archive (4)/Tokyo Medals 2021.csv", index_col=0)
df_tokio
# Out:
#                             Gold Medal  Silver Medal  Bronze Medal  Total  \
# Country
# United States of America            39            41            33    113
# People's Republic of China          38            32            18     88
# Japan                               27            14            17     58
# Great Britain                       22            21            22     65
# ROC                                 20            28            23     71
# ...                                ...           ...           ...    ...
# Ghana                                0             0             1      1
# Grenada                              0             0             1      1
# Kuwait                               0             0             1      1
# Republic of Moldova                  0             0             1      1
# Syrian Arab Republic                 0             0             1      1
#
#                             Rank By Total
# Country
# ...

# %%
df_paris = pd.read_csv("C:/Users/ANALISIS DE DATOS.1-21-01-E019-27/Desktop/Datasets/archive (5)/olympics2024.csv", index_col=0)
df_paris
# Out:
#             Country Country Code  Gold  Silver  Bronze  Total
# Rank
# 1     United States           US    40      44      42    126
# 2             China          CHN    40      27      24     91
# 3             Japan          JPN    20      12      13     45
# 4         Australia          AUS    18      19      16     53
# 5            France          FRA    16      26      22     64
# ...             ...          ...   ...     ...     ...    ...
# 84             Peru          PER     0       0       1      1
# 84            Qatar          QAT     0       0       1      1
# 84        Singapore          SIN     0       0       1      1
# 84         Slovakia          SVK     0       0       1      1
# 84           Zambia          ZAM     0       0       1      1
#
# [91 rows x 6 columns]

# %%
df_pbi = pd.read_csv("C:/Users/ANALISIS DE DATOS.1-21-01-E019-27/Desktop/Datasets/archive (6)/Per Capita GDP of All Countries 1970 to 2022.csv", index_col=0)
df_pbi
# Out:
#                             Country         1970         1971         1972  \
# Sr.No
# 1                       Afghanistan   162.642176   166.224832   141.365323
# 2                           Albania   974.554499   975.216820   976.521166
# 3                           Algeria   373.670080   380.125666   496.991248
# 4                           Andorra  5008.901637  5305.716707  6285.301526
# 5                            Angola   631.514939   648.910896   644.659613
# ...                             ...          ...          ...          ...
# 183    Yemen Arab Republic (Former)    76.222959    87.998562   124.898913
# 184       Yemen Democratic (Former)    94.929351    85.003136    92.397759
# 185             Yugoslavia (Former)   704.150562   757.937976   783.579953
# 186                          Zambia   360.651807   357.771353   409.332165
# 187                        Zimbabwe   449.078443   503.731409   603.030370
#
# ...

# %%
df_paris = df_paris.to_csv("CsvParis.csv", index = False)

# %%
df_pbi = df_pbi.to_json("PBI.json", orient="records")

# %%
df_tokio = df_tokio.to_csv("CsvTokio.csv")
